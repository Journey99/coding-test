# %% [markdown]
# ## Hash Map & Set
#
# ### hash란?
# > 어떤 값을 고정된 크기의 숫자로 빠르게 매핑하는 함수
# > 예를 들어 문자열 'abc' 를 숫자 129381923 같은 값으로 바꿔버리는 것
#
# ### hash map이란?
# > Key-value 형태로 데이터를 저장하는 자료구조
# > 파이썬에서는 dict 형태
# > 언제 사용 ? 어떤 값을 빠르게 찾고 싶을 때, 빈도 계산, 두 값의 관계 저장, 맵핑 문제
#
# ### hast set이란?
# > 중복 없는 값들의 집합
# > 파이썬에서는 set 형태
# > 언제 사용 ? 방문 여부 체크, 중복 확인, 존재 여부 검색, unique 값 관리

# %% [markdown]
# ---
#
# ### 2215. Find the Difference of Two Arrays
# Given two 0-indexed integer arrays nums1 and nums2, return a list answer of size 2 where:
#
# - answer[0] is a list of all distinct integers in nums1 which are not present in nums2.
# - answer[1] is a list of all distinct integers in nums2 which are not present in nums1.
#
# Note that the integers in the lists may be returned in any order.

# %%
from typing import List

class Solution:
    def findDifference(self, nums1: List[int], nums2: List[int]) -> List[List[int]]:
        nums1 = set(nums1)
        nums2 = set(nums2)

        return [list(nums1-nums2), list(nums2-nums1)]

# %% [markdown]
# ---
#
# ### 1207. Unique Number of Occurrences
# Given an array of integers arr, return true if the number of occurrences of each value in the array is unique or false otherwise.

# %%
class Solution:
    def uniqueOccurrences(self, arr: List[int]) -> bool:
        setarr = set(arr)
        cnt = []

        for s in setarr:
            cnt.append(arr.count(s))
        
        if len(cnt) == len(set(cnt)):
            return True
        else:
            return False
        

s = Solution()
print(s.uniqueOccurrences([1,2,2,1,1,3]))
# Out:
# True

# %%
class Solution:
    def uniqueOccurrences(self, arr: List[int]) -> bool:
        s = sorted(arr)

        dic = {}
        for item in s:
            dic[item] = dic.get(item, 0) + 1

        cnt = []
        for k, v in dic.items():
            if v not in cnt:
                cnt.append(v)
            else:
                return False
        
        return True

# %% [markdown]
# ---
#
# ### 1657. Determine if Two Strings Are Close
# Two strings are considered close if you can attain one from the other using the following operations:
#
# - Operation 1: Swap any two existing characters.
#   - For example, abcde -> aecdb
# - Operation 2: Transform every occurrence of one existing character into another existing character, and do the same with the other character.
#   - For example, aacabb -> bbcbaa (all a's turn into b's, and all b's turn into a's)
#
# You can use the operations on either string as many times as necessary.
#
# Given two strings, word1 and word2, return true if word1 and word2 are close, and false otherwise.

# %%
'''
operation1 : 두 문자열의 글자 구성이 같아야 한다 = set이 같아야함
operation2 : 글자 빈도수가 같아야 함 
ex) aacabb = [3,1,2] -> [1,2,3]
    bbcbaa = [3,1,2] -> [1,2,3]
'''

class Solution:
    def closeStrings(self, word1: str, word2: str) -> bool:
        s_w1 = set(word1)
        s_w2 = set(word2)

        if s_w1 != s_w2:
            return False

        cnt1, cnt2 = [], []

        for s in s_w1:
            cnt1.append(word1.count(s))
            cnt2.append(word2.count(s))

        cnt1.sort()
        cnt2.sort()

        if cnt1 == cnt2:
            return True
        
        return False


# Counter를 사용해 다듬은 코드
from collections import Counter

class Solution:
    def closeStrings(self, word1: str, word2: str) -> bool:
        if set(word1) != set(word2):
            return False
        
        freq_w1 = Counter(word1)
        freq_w2 = Counter(word2)

        res_w1 = sorted(freq_w1.values())
        res_w2 = sorted(freq_w2.values())

        return res_w1 == res_w2

# %% [markdown]
# ---
#
# ### 2352. Equal Row and Column Pairs
# Given a 0-indexed n x n integer matrix grid, return the number of pairs (ri, cj) such that row ri and column cj are equal.
#
# A row and column pair is considered equal if they contain the same elements in the same order (i.e., an equal array).

# %%
from typing import List

class Solution:
    def equalPairs(self, grid: List[List[int]]) -> int:
        
        r_cnt = {}
        for row in grid:
            t = tuple(row)
            r_cnt[t] = r_cnt.get(t, 0) + 1

        c_grid = list(zip(*grid))
        
        ans = 0
        for c in c_grid:
            if c in r_cnt:
                ans += r_cnt[c]

        return ans


s = Solution()
s.equalPairs([[3,2,1],[1,7,6],[2,7,7]])
# Out:
# [(3, 1, 2), (2, 7, 7), (1, 6, 7)]
# 0
